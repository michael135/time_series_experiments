# %%
# %matplotlib inline
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('market_data.csv').drop(columns=['Time'])

# %%
data.index = data.index.astype('float')

# %%
random_indexes = range(data.shape[1])
random.shuffle(random_indexes)

for i in random_indexes[:50]:
    plt.figure()
    first, second = data.iloc[:60, i], data.iloc[60:, i]
    title = 'first min = {:.5f}, second min = {:.5f}, first max = {:.4f} second max = {:.4f}'.\
    format(first.min(), second.min(), first.max(), second.max())
    
    data.iloc[:, i].plot(title=title);
    plt.axvline(60, color='red')
    sns.regplot(x='Unnamed: 0', y=data.columns[i], data=data.loc[:60, ['Unnamed: 0', data.columns[i]]], fit_reg=True)
#     sns.regplot(data=data.iloc[:, i], fit_reg=True) 
#     print data.iloc[:60,i].min()
